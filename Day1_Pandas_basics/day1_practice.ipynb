# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. Load Dataset
#
# (Downloaded from Kaggle and place the CSV in my working folder)

# %%
df= pd.read_csv('Titanic-Dataset.csv')
df.head()
